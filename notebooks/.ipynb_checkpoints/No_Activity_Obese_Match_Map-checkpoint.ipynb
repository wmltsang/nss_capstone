# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import FloatImage
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
import time
import numpy as np
import branca.colormap as cm

# %%
match_frame = pd.read_csv('../data/no_activity_latlon.csv')
match_frame.head()
# Out:
#    Unnamed: 0  Year StateAbbr  StateDesc     CityName GeographicLevel  \
# 0           0  2017        TN  Tennessee    Knoxville    Census Tract
# 1           1  2017        TN  Tennessee  Clarksville    Census Tract
# 2           2  2017        TN  Tennessee  Chattanooga    Census Tract
# 3           3  2017        TN  Tennessee  Chattanooga    Census Tract
# 4           4  2017        TN  Tennessee    Knoxville    Census Tract
#
#   DataSource             Category  \
# 0      BRFSS  Unhealthy Behaviors
# 1      BRFSS  Unhealthy Behaviors
# 2      BRFSS  Unhealthy Behaviors
# 3      BRFSS  Unhealthy Behaviors
# 4      BRFSS  Unhealthy Behaviors
#
#                                              Measure Data_Value_Unit  ...  \
# 0  No leisure-time physical activity among adults...               %  ...
# 1  No leisure-time physical activity among adults...               %  ...
# 2  No leisure-time physical activity among adults...               %  ...
# 3  No leisure-time physical activity among adults...               %  ...
# 4  No leisure-time physical activity among adults...               %  ...
#
#   MeasureId CityFIPS     TractFIPS  Short_Question_Text      n_lat      n_lon  \
# 0       LPA  4740000  4.709300e+10  Physical Inactivity  35.123371 -85.249368
# 1       LPA  4715160  4.712510e+10  Physical Inactivity  36.019985 -83.940415
# 2       LPA  4714000  4.706501e+10  Physical Inactivity  35.055331 -85.333062
# 3       LPA  4714000  4.706500e+10  Physical Inactivity  36.003542 -83.939873
# 4       LPA  4740000  4.709300e+10  Physical Inactivity  35.998590 -83.972815
#
#               UniqueID      o_lat      o_lon distance
# 0  4714000-47065010433  35.123371 -85.249368      0.0
# 1  4740000-47093004100  36.019985 -83.940415      0.0
# 2  4714000-47065010901  35.055331 -85.333062      0.0
# 3  4740000-47093002900  36.003542 -83.939873      0.0
# 4  4740000-47093003902  35.998590 -83.972815      0.0
#
# [5 rows x 30 columns]

# %%
geometry = [Point(xy) for xy in zip(match_frame.n_lon, match_frame.n_lat)]
# cluster_frame = cluster_frame.drop(['Latitude', 'Longitude'], axis=1)
match_geo = gpd.GeoDataFrame(match_frame, crs="EPSG:4326", geometry=geometry)

# %%
match_map = folium.Map(location = [35.123371, -85.249368], zoom_start = 12)
folium.TileLayer('Mapbox Control Room').add_to(match_map)

# %%
print(match_geo['PopulationCount'].max())
# Out:
# 956

# %%
colormap = cm.LinearColormap(colors=['lightblue','red'], index=[0,10000],vmin=90,vmax=10000)

# %%
for row_index, row_values in match_geo.iterrows():
    loc = [row_values['n_lat'], row_values['n_lon']]
    pop = 'Obese/No Activity Match:' + (' ') + row_values['CityName'] + ', ' + row_values['StateAbbr']+ (' ') + 'Population Count: '+ row_values['PopulationCount']
    marker = folium.Marker(
        location = loc,
        icon = folium.Icon(color = 'red',icon="user-md", prefix = 'fa'),  #icon is not popping up ref:https://fontawesome.com/icons/weight?style=solid
#        radius=100,
        popup = pop,
        fill=True,)
        #color=colormap(??????))  # I want to add color scale to population count (popup with higher pop count, the darker red)
                                    #how to add legend with the icons and color scale
        
    
    marker.add_to(match_map)

# %%
for row_index, row_values in match_geo.iterrows():
    loc = [row_values['o_lat'], row_values['o_lon']]
    marker = folium.Circle(
        location = loc,
        radius=200,
        fill=True,
        color='blue') 
    
    marker.add_to(match_map)

#use imgur to upload picture and get direct link of url and ref guide is: https://flashissue.zendesk.com/hc/en-us/articles/216491878-Host-an-image-imgur-com-
    url = ('https://i.imgur.com/erBuseO.jpg')
folium.plugins.FloatImage(url, bottom=75, left=80).add_to(match_map)

# %%
match_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#how to add icon on map and how to add scale color change on population count
match_map.save('../maps/obese_no_activity_match_map.html')

# %%
# how to export html file from desktop to a url with http or https
