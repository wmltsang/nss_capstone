# %% [markdown]
# ## chronic diseases indicators (CDI) Analysis

# %% [markdown]
# Analysis on lifestyle factors on health in Nashville/Tennessee

# %% [markdown]
# #### Import library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Formatting

# %%
# %matplotlib inline

# %%
#import csv file: U.S._Chronic_Disease_Indicators__CDI_.master
us_cdi_df = pd.read_csv('../data/U.S._Chronic_Disease_Indicators__CDI_.master.csv', low_memory=False)

# %%
#look at head
us_cdi_df.head(5)
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2010     2014           WA   Washington
# 1       2009     2013           OR       Oregon
# 2       2009     2013           FL      Florida
# 3       2010     2014           MI     Michigan
# 4       2010     2014           KY     Kentucky
#
#                             DataSource   Topic  \
# 0                    Death Certificate  Cancer
# 1  Statewide central cancer registries  Cancer
# 2                    Death Certificate  Cancer
# 3  Statewide central cancer registries  Cancer
# 4  Statewide central cancer registries  Cancer
#
#                                             Question  Response DataValueUnit  \
# 0  Cancer of the colon and rectum (colorectal), m...       NaN   per 100,000
# 1    Invasive cancer (all sites combined), incidence       NaN   per 100,000
# 2   Cancer of the oral cavity and pharynx, mortality       NaN   per 100,000
# 3         Cancer of the lung and bronchus, incidence       NaN           NaN
# 4         Cancer of the lung and bronchus, incidence       NaN   per 100,000
#
#                       DataValueType  ... LocationID TopicID QuestionID  \
# 0  Average Annual Age-adjusted Rate  ...         53     CAN     CAN7_2
# 1  Average Annual Age-adjusted Rate  ...         41     CAN     CAN4_1
# 2         Average Annual Crude Rate  ...         12     CAN    CAN10_2
# 3             Average Annual Number  ...         26     CAN     CAN8_1
# 4         Average Annual Crude Rate  ...         21     CAN     CAN8_1
#
#     DataValueTypeID StratificationCategoryID1 StratificationID1  \
# 0  AVGANNAGEADJRATE                    GENDER              GENM
# 1  AVGANNAGEADJRATE                      RACE               WHT
# 2     AVGANNCRDRATE                      RACE              AIAO
# 3        AVGANNNMBR                      RACE               WHT
# 4     AVGANNCRDRATE                      RACE              AIAO
#
#   StratificationCategoryID2 StratificationID2  StratificationCategoryID3  \
# 0                       NaN               NaN                        NaN
# 1                       NaN               NaN                        NaN
# 2                       NaN               NaN                        NaN
# 3                       NaN               NaN                        NaN
# 4                       NaN               NaN                        NaN
#
#    StratificationID3
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 34 columns]

# %%
#look at tail
us_cdi_df.tail(5)
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc  \
# 814932       2009     2013           NM            New Mexico
# 814933       2009     2013           AL               Alabama
# 814934       2010     2014           OH                  Ohio
# 814935       2009     2013           SC        South Carolina
# 814936       2009     2013           DC  District of Columbia
#
#                                  DataSource   Topic  \
# 814932                    Death Certificate  Cancer
# 814933  Statewide central cancer registries  Cancer
# 814934                    Death Certificate  Cancer
# 814935                    Death Certificate  Cancer
# 814936                    Death Certificate  Cancer
#
#                                                  Question  Response  \
# 814932    Invasive cancer (all sites combined), mortality       NaN
# 814933  Invasive cancer of the oral cavity or pharynx,...       NaN
# 814934         Cancer of the lung and bronchus, mortality       NaN
# 814935    Invasive cancer (all sites combined), mortality       NaN
# 814936   Cancer of the oral cavity and pharynx, mortality       NaN
#
#        DataValueUnit                     DataValueType  ... LocationID  \
# 814932           NaN             Average Annual Number  ...         35
# 814933   per 100,000  Average Annual Age-adjusted Rate  ...          1
# 814934   per 100,000  Average Annual Age-adjusted Rate  ...         39
# 814935   per 100,000  Average Annual Age-adjusted Rate  ...         45
# 814936           NaN             Average Annual Number  ...         11
#
#        TopicID QuestionID   DataValueTypeID StratificationCategoryID1  \
# 814932     CAN     CAN4_2        AVGANNNMBR                   OVERALL
# 814933     CAN    CAN10_1  AVGANNAGEADJRATE                      RACE
# 814934     CAN     CAN8_2  AVGANNAGEADJRATE                   OVERALL
# 814935     CAN     CAN4_2  AVGANNAGEADJRATE                      RACE
# 814936     CAN    CAN10_2        AVGANNNMBR                      RACE
#
#        StratificationID1 StratificationCategoryID2 StratificationID2  \
# 814932               OVR                       NaN               NaN
# 814933               WHT                       NaN               NaN
# 814934               OVR                       NaN               NaN
# 814935               HIS                       NaN               NaN
# 814936              AIAO                       NaN               NaN
#
#         StratificationCategoryID3  StratificationID3
# 814932                        NaN                NaN
# 814933                        NaN                NaN
# 814934                        NaN                NaN
# 814935                        NaN                NaN
# 814936                        NaN                NaN
#
# [5 rows x 34 columns]

# %%
# examine shape of us cdi df
#814937 rows, 34 columns
us_cdi_df.shape
# Out:
# (814937, 34)

# %%
#examine info of us cdi df
us_cdi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 814937 entries, 0 to 814936
# Data columns (total 34 columns):
# YearStart                    814937 non-null int64
# YearEnd                      814937 non-null int64
# LocationAbbr                 814937 non-null object
# LocationDesc                 814937 non-null object
# DataSource                   814937 non-null object
# Topic                        814937 non-null object
# Question                     814937 non-null object
# Response                     0 non-null float64
# DataValueUnit                728402 non-null object
# DataValueType                814937 non-null object
# DataValue                    555277 non-null object
# DataValueAlt                 554139 non-null object
# DataValueFootnoteSymbol      270821 non-null object
# DatavalueFootnote            270821 non-null object
# LowConfidenceLimit           475125 non-null object
# HighConfidenceLimit          475125 non-null object
# StratificationCategory1      814937 non-null object
# Stratification1              814937 non-null object
# StratificationCategory2      0 non-null float64
# Stratification2              0 non-null float64
# StratificationCategory3      0 non-null float64
# Stratification3              0 non-null float64
# GeoLocation                  808141 non-null object
# ResponseID                   0 non-null float64
# LocationID                   814937 non-null int64
# TopicID                      814937 non-null object
# QuestionID                   814937 non-null object
# DataValueTypeID              814937 non-null object
# StratificationCategoryID1    814937 non-null object
# StratificationID1            814937 non-null object
# StratificationCategoryID2    0 non-null float64
# StratificationID2            0 non-null float64
# StratificationCategoryID3    0 non-null float64
# StratificationID3            0 non-null float64
# dtypes: float64(10), int64(3), object(21)
# memory usage: 211.4+ MB

# %%
# drop unecessary columns in us cdi df 
us_cdi_df = us_cdi_df.drop(columns = ['LocationAbbr','Response', 'DataValueFootnoteSymbol','DatavalueFootnote','LowConfidenceLimit','HighConfidenceLimit','StratificationCategory2','Stratification2','StratificationCategory3','Stratification3','ResponseID','LocationID','TopicID','QuestionID','DataValueTypeID','StratificationCategoryID1','StratificationID1','StratificationCategoryID2','StratificationCategoryID3','StratificationID2','StratificationID3'])

# %%
#look at column names now
us_cdi_df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationDesc', 'DataSource', 'Topic',
#        'Question', 'DataValueUnit', 'DataValueType', 'DataValue',
#        'DataValueAlt', 'StratificationCategory1', 'Stratification1',
#        'GeoLocation'],
#       dtype='object')

# %%
# change YearEnd to datetimeindex format
us_cdi_df['YearEnd'] = pd.DatetimeIndex(us_cdi_df['YearEnd'])

# %%
# want to subset to have topic of Nutrition, Physical Activity, and Weight Status on topic column

#need to subset multiple columns based on mulitple conditions

# us_cdi_df to only have DataSource col 'BRFSS' and DataValueType be 'Crude Prevalence'
## example of exact match subset dogs["breed"] == "Labrador"

# brfss and cp subset
brfss = us_cdi_df['DataSource'] == 'BRFSS'
cp    = us_cdi_df['DataValueType']== 'Crude Prevalence'
us_cdi_brfss_cp = us_cdi_df[brfss & cp]

# DataSource needs to be 'BRFSS', Topic be 'Nutrition, Physical Activity, and Weight Status', DataValueType be 'Crude Prevalence'
# brfss and cp and npw subset

npw = us_cdi_df['Topic']== 'Nutrition, Physical Activity, and Weight Status'
us_cdi_brfss_npw_cp = us_cdi_df[brfss & cp & npw]

# %%
us_cdi_brfss_cp.head()
# Out:
#       YearStart                       YearEnd LocationDesc DataSource  \
# 813        2013 1970-01-01 00:00:00.000002013  Mississippi      BRFSS
# 1419       2015 1970-01-01 00:00:00.000002015      Arizona      BRFSS
# 3469       2014 1970-01-01 00:00:00.000002014     Arkansas      BRFSS
# 4077       2018 1970-01-01 00:00:00.000002018     Virginia      BRFSS
# 4148       2018 1970-01-01 00:00:00.000002018        Idaho      BRFSS
#
#           Topic                                           Question  \
# 813   Arthritis  Fair or poor health among adults aged >= 18 ye...
# 1419  Arthritis            Arthritis among adults aged >= 18 years
# 3469    Alcohol       Heavy drinking among adults aged >= 18 years
# 4077     Asthma  Pneumococcal vaccination among noninstitutiona...
# 4148     Asthma     Asthma prevalence among women aged 18-44 years
#
#      DataValueUnit     DataValueType DataValue DataValueAlt  \
# 813              %  Crude Prevalence      46.9         46.9
# 1419             %  Crude Prevalence      23.6         23.6
# 3469             %  Crude Prevalence       6.0            6
# 4077             %  Crude Prevalence      36.6         36.6
# 4148             %  Crude Prevalence      12.4         12.4
#
#      StratificationCategory1      Stratification1  \
# 813                   Gender                 Male
# 1419                 Overall              Overall
# 3469                  Gender                 Male
# 4077                  Gender                 Male
# 4148          Race/Ethnicity  White, non-Hispanic
#
#                                     GeoLocation
# 813    (32.745510099000455, -89.53803082499968)
# 1419  (34.865970280000454, -111.76381127699972)
# 3469    (34.74865012400045, -92.27449074299966)
# 4077    (37.54268067400045, -78.45789046299967)
# 4148   (43.682630005000476, -114.3637300419997)

# %%
us_cdi_brfss_npw_cp.head()
# Out:
#        YearStart                       YearEnd  LocationDesc DataSource  \
# 29332       2018 1970-01-01 00:00:00.000002018  North Dakota      BRFSS
# 32562       2018 1970-01-01 00:00:00.000002018          Utah      BRFSS
# 32687       2018 1970-01-01 00:00:00.000002018      Oklahoma      BRFSS
# 34092       2018 1970-01-01 00:00:00.000002018     Wisconsin      BRFSS
# 34098       2018 1970-01-01 00:00:00.000002018       Montana      BRFSS
#
#                                                  Topic  \
# 29332  Nutrition, Physical Activity, and Weight Status
# 32562  Nutrition, Physical Activity, and Weight Status
# 32687  Nutrition, Physical Activity, and Weight Status
# 34092  Nutrition, Physical Activity, and Weight Status
# 34098  Nutrition, Physical Activity, and Weight Status
#
#                                                 Question DataValueUnit  \
# 29332  No leisure-time physical activity among adults...             %
# 32562              Obesity among adults aged >= 18 years             %
# 32687  Overweight or obesity among adults aged >= 18 ...             %
# 34092              Obesity among adults aged >= 18 years             %
# 34098       Healthy weight among adults aged >= 18 years             %
#
#           DataValueType DataValue DataValueAlt StratificationCategory1  \
# 29332  Crude Prevalence      22.3         22.3                 Overall
# 32562  Crude Prevalence      30.0           30          Race/Ethnicity
# 32687  Crude Prevalence      68.9         68.9          Race/Ethnicity
# 34092  Crude Prevalence      40.3         40.3          Race/Ethnicity
# 34098  Crude Prevalence      32.9         32.9          Race/Ethnicity
#
#            Stratification1                                GeoLocation
# 29332              Overall   (47.47531977900047, -100.11842104899966)
# 32562             Hispanic  (39.360700171000474, -111.58713063499971)
# 32687  White, non-Hispanic    (35.47203135600046, -97.52107021399968)
# 34092             Hispanic    (44.39319117400049, -89.81637074199966)
# 34098             Hispanic   (47.06652897200047, -109.42442064499971)

# %%
# three conditions for questions subset see notes of capstone proposal

#Row contains string ‘consumption’ mean the person fruit and vegetable consumption frequency
## example of isin subset is_black_or_brown = dogs["color"].isin(["Black", "Brown"]) #this isin code has an error
## df[df['A'].str.contains("hello")]
nutrition_intake_consump = us_cdi_df[us_cdi_df['Question'].str.contains("consumption")]
nutrition_intake_consump.head()
#us_cdi_brfss_npw_cp_consump = us_cdi_df[brfss & cp & npw & nutrition_intake_consump]

#There are so many filters within the data set of us cdc dataframe and i did a general analysis with excel. See notes in capstone
# Out:
#        YearStart                       YearEnd   LocationDesc DataSource  \
# 34319       2017 1970-01-01 00:00:00.000002017  New Hampshire      YRBSS
# 34331       2017 1970-01-01 00:00:00.000002017        Montana      YRBSS
# 34372       2017 1970-01-01 00:00:00.000002017     California      YRBSS
# 35530       2016 1970-01-01 00:00:00.000002016        Georgia       AEDS
# 35557       2016 1970-01-01 00:00:00.000002016       Delaware       AEDS
#
#                                                  Topic  \
# 34319  Nutrition, Physical Activity, and Weight Status
# 34331  Nutrition, Physical Activity, and Weight Status
# 34372  Nutrition, Physical Activity, and Weight Status
# 35530                                          Alcohol
# 35557                                          Alcohol
#
#                                                 Question DataValueUnit  \
# 34319        Soda consumption among high school students             %
# 34331        Soda consumption among high school students             %
# 34372        Soda consumption among high school students             %
# 35530  Per capita alcohol consumption among persons a...       gallons
# 35557  Per capita alcohol consumption among persons a...       gallons
#
#                         DataValueType DataValue DataValueAlt  \
# 34319                Crude Prevalence      11.7         11.7
# 34331                Crude Prevalence      10.9         10.9
# 34372                Crude Prevalence      13.2         13.2
# 35530  Per capita alcohol consumption       1.9          1.9
# 35557  Per capita alcohol consumption       3.7          3.7
#
#       StratificationCategory1      Stratification1  \
# 34319          Race/Ethnicity  Asian, non-Hispanic
# 34331                  Gender               Female
# 34372          Race/Ethnicity  Black, non-Hispanic
# 35530                 Overall              Overall
# 35557                 Overall              Overall
#
#                                     GeoLocation
# 34319   (43.65595011300047, -71.50036091999965)
# 34331  (47.06652897200047, -109.42442064499971)
# 34372  (37.63864012300047, -120.99999953799971)
# 35530   (32.83968109300048, -83.62758034599966)
# 35557  (39.008830667000495, -75.57774116799965)

# %%
#import for only obesity dataset to explore relationship between obesity and nutrition intake and excercise
# inner joins obesity data,nutrition and exercise after apply filters formula

#import csv file: Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System
us_obesity_df = pd.read_csv('../data/Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv')

# %%
# examine us_obesity_df head

us_obesity_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc  \
# 0       2012     2012           WY               Wyoming
# 1       2012     2012           DC  District of Columbia
# 2       2011     2011           AL               Alabama
# 3       2013     2013           US              National
# 4       2011     2011           US              National
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System        Physical Activity
# 4  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                           Topic  \
# 0       Obesity / Weight Status
# 1       Obesity / Weight Status
# 2       Obesity / Weight Status
# 3  Physical Activity - Behavior
# 4  Physical Activity - Behavior
#
#                                             Question  Data_Value_Unit  \
# 0  Percent of adults aged 18 years and older who ...              NaN
# 1  Percent of adults aged 18 years and older who ...              NaN
# 2  Percent of adults aged 18 years and older who ...              NaN
# 3  Percent of adults who engage in no leisure-tim...              NaN
# 4  Percent of adults who engage in no leisure-tim...              NaN
#
#   Data_Value_Type  ...                     GeoLocation  ClassID TopicID  \
# 0           Value  ...  (43.235541343, -108.109830353)      OWS    OWS1
# 1           Value  ...   (38.890371385, -77.031961127)      OWS    OWS1
# 2           Value  ...   (32.840571122, -86.631860762)      OWS    OWS1
# 3           Value  ...                             NaN       PA     PA1
# 4           Value  ...                             NaN       PA     PA1
#
#   QuestionID  DataValueTypeID  LocationID StratificationCategory1  \
# 0       Q037            VALUE          56          Race/Ethnicity
# 1       Q036            VALUE          11               Education
# 2       Q036            VALUE           1             Age (years)
# 3       Q047            VALUE          59                  Gender
# 4       Q047            VALUE          59             Age (years)
#
#                  Stratification1 StratificationCategoryId1 StratificationID1
# 0  American Indian/Alaska Native                      RACE           RACENAA
# 1          Less than high school                       EDU             EDUHS
# 2                        25 - 34                     AGEYR         AGEYR2534
# 3                         Female                       GEN            FEMALE
# 4                        18 - 24                     AGEYR         AGEYR1824
#
# [5 rows x 33 columns]

# %%
#dataframe info

us_obesity_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63028 entries, 0 to 63027
# Data columns (total 33 columns):
# YearStart                     63028 non-null int64
# YearEnd                       63028 non-null int64
# LocationAbbr                  63028 non-null object
# LocationDesc                  63028 non-null object
# Datasource                    63028 non-null object
# Class                         63028 non-null object
# Topic                         63028 non-null object
# Question                      63028 non-null object
# Data_Value_Unit               0 non-null float64
# Data_Value_Type               63028 non-null object
# Data_Value                    56796 non-null float64
# Data_Value_Alt                56796 non-null float64
# Data_Value_Footnote_Symbol    6232 non-null object
# Data_Value_Footnote           6232 non-null object
# Low_Confidence_Limit          56796 non-null float64
# High_Confidence_Limit         56796 non-null float64
# Sample_Size                   56796 non-null object
# Total                         2251 non-null object
# Age(years)                    13506 non-null object
# Education                     9004 non-null object
# Gender                        4502 non-null object
# Income                        15757 non-null object
# Race/Ethnicity                18008 non-null object
# GeoLocation                   61852 non-null object
# ClassID                       63028 non-null object
# TopicID                       63028 non-null object
# QuestionID                    63028 non-null object
# DataValueTypeID               63028 non-null object
# LocationID                    63028 non-null int64
# StratificationCategory1       63028 non-null object
# Stratification1               63028 non-null object
# StratificationCategoryId1     63028 non-null object
# StratificationID1             63028 non-null object
# dtypes: float64(5), int64(3), object(25)
# memory usage: 15.9+ MB

# %%
# subset obeisty values
#use Question contains to subset  
## df[df['A'].str.contains("hello")]

#explore if there are ways to transpose rows to columns grouping by topics and sub topics and show their values
#trying df.pivot(column='var',values = 'val') that spread rows into columns

#by_topic = us_obesity_df.pivot(columns='Topic', values='Data_Value')
#it does not work as there are no matching values for each column

# %%
#try groupby

by_topic = us_obesity_df.groupby(by='Topic')

# %%
by_topic.head()
# Out:
#       YearStart  YearEnd LocationAbbr          LocationDesc  \
# 0          2012     2012           WY               Wyoming
# 1          2012     2012           DC  District of Columbia
# 2          2011     2011           AL               Alabama
# 3          2013     2013           US              National
# 4          2011     2011           US              National
# 5          2011     2011           US              National
# 6          2011     2011           US              National
# 7          2015     2015           RI          Rhode Island
# 8          2012     2012           WY               Wyoming
# 10         2011     2011           WA            Washington
# 6828       2017     2017           MT               Montana
# 6839       2017     2017           DC  District of Columbia
# 6902       2017     2017           AZ               Arizona
# 6908       2017     2017           NY              New York
# 6910       2017     2017           NY              New York
#
#                                       Datasource                    Class  \
# 0     Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1     Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2     Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3     Behavioral Risk Factor Surveillance System        Physical Activity
# 4     Behavioral Risk Factor Surveillance System        Physical Activity
# 5     Behavioral Risk Factor Surveillance System        Physical Activity
# 6     Behavioral Risk Factor Surveillance System        Physical Activity
# 7     Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 8     Behavioral Risk Factor Surveillance System        Physical Activity
# 10    Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 6828  Behavioral Risk Factor Surveillance System    Fruits and Vegetables
# 6839  Behavioral Risk Factor Surveillance System    Fruits and Vegetables
# 6902  Behavioral Risk Factor Surveillance System    Fruits and Vegetables
# 6908  Behavioral Risk Factor Surveillance System    Fruits and Vegetables
# 6910  Behavioral Risk Factor Surveillance System    Fruits and Vegetables
#
#                                  Topic  \
# 0              Obesity / Weight Status
# 1              Obesity / Weight Status
# 2              Obesity / Weight Status
# 3         Physical Activity - Behavior
# 4         Physical Activity - Behavior
# 5         Physical Activity - Behavior
# 6         Physical Activity - Behavior
# 7              Obesity / Weight Status
# 8         Physical Activity - Behavior
# 10             Obesity / Weight Status
# 6828  Fruits and Vegetables - Behavior
# 6839  Fruits and Vegetables - Behavior
# 6902  Fruits and Vegetables - Behavior
# 6908  Fruits and Vegetables - Behavior
# 6910  Fruits and Vegetables - Behavior
#
#                                                Question  Data_Value_Unit  \
# 0     Percent of adults aged 18 years and older who ...              NaN
# 1     Percent of adults aged 18 years and older who ...              NaN
# 2     Percent of adults aged 18 years and older who ...              NaN
# 3     Percent of adults who engage in no leisure-tim...              NaN
# 4     Percent of adults who engage in no leisure-tim...              NaN
# 5     Percent of adults who engage in no leisure-tim...              NaN
# 6     Percent of adults who engage in no leisure-tim...              NaN
# 7     Percent of adults aged 18 years and older who ...              NaN
# 8     Percent of adults who engage in no leisure-tim...              NaN
# 10    Percent of adults aged 18 years and older who ...              NaN
# 6828  Percent of adults who report consuming vegetab...              NaN
# 6839  Percent of adults who report consuming vegetab...              NaN
# 6902  Percent of adults who report consuming fruit l...              NaN
# 6908  Percent of adults who report consuming vegetab...              NaN
# 6910  Percent of adults who report consuming vegetab...              NaN
#
#      Data_Value_Type  ...                     GeoLocation  ClassID TopicID  \
# 0              Value  ...  (43.235541343, -108.109830353)      OWS    OWS1
# 1              Value  ...   (38.890371385, -77.031961127)      OWS    OWS1
# 2              Value  ...   (32.840571122, -86.631860762)      OWS    OWS1
# 3              Value  ...                             NaN       PA     PA1
# 4              Value  ...                             NaN       PA     PA1
# 5              Value  ...                             NaN       PA     PA1
# 6              Value  ...                             NaN       PA     PA1
# 7              Value  ...   (41.708280193, -71.522470314)      OWS    OWS1
# 8              Value  ...  (43.235541343, -108.109830353)       PA     PA1
# 10             Value  ...   (47.522278629, -120.47001079)      OWS    OWS1
# 6828           Value  ...  (47.066528972, -109.424420645)       FV     FV1
# 6839           Value  ...   (38.890371385, -77.031961127)       FV     FV1
# 6902           Value  ...   (34.86597028, -111.763811277)       FV     FV1
# 6908           Value  ...   (42.827001032, -75.543970427)       FV     FV1
# 6910           Value  ...   (42.827001032, -75.543970427)       FV     FV1
#
#      QuestionID  DataValueTypeID  LocationID StratificationCategory1  \
# 0          Q037            VALUE          56          Race/Ethnicity
# 1          Q036            VALUE          11               Education
# 2          Q036            VALUE           1             Age (years)
# 3          Q047            VALUE          59                  Gender
# 4          Q047            VALUE          59             Age (years)
# 5          Q047            VALUE          59             Age (years)
# 6          Q047            VALUE          59             Age (years)
# 7          Q037            VALUE          44          Race/Ethnicity
# 8          Q047            VALUE          56                  Income
# 10         Q037            VALUE          53                  Gender
# 6828       Q019            VALUE          30               Education
# 6839       Q019            VALUE          11             Age (years)
# 6902       Q018            VALUE           4          Race/Ethnicity
# 6908       Q019            VALUE          36                  Income
# 6910       Q019            VALUE          36                  Income
#
#                        Stratification1 StratificationCategoryId1  \
# 0        American Indian/Alaska Native                      RACE
# 1                Less than high school                       EDU
# 2                              25 - 34                     AGEYR
# 3                               Female                       GEN
# 4                              18 - 24                     AGEYR
# 5                              25 - 34                     AGEYR
# 6                              55 - 64                     AGEYR
# 7                             Hispanic                      RACE
# 8                    Less than $15,000                       INC
# 10                                Male                       GEN
# 6828  Some college or technical school                       EDU
# 6839                       65 or older                     AGEYR
# 6902         Hawaiian/Pacific Islander                      RACE
# 6908                 $50,000 - $74,999                       INC
# 6910                 Less than $15,000                       INC
#
#      StratificationID1
# 0              RACENAA
# 1                EDUHS
# 2            AGEYR2534
# 3               FEMALE
# 4            AGEYR1824
# 5            AGEYR2534
# 6            AGEYR5564
# 7              RACEHIS
# 8            INCLESS15
# 10                MALE
# 6828          EDUCOTEC
# 6839       AGEYR65PLUS
# 6902           RACEHPI
# 6908           INC5075
# 6910         INCLESS15
#
# [15 rows x 33 columns]

# %%
#figure out duplicate in excel file
